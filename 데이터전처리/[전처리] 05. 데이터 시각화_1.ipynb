# %% [markdown]
# ## **Data Visualization -1**
#
# 기본적인 데이터 시각화 방법을 살펴봅니다.

# %%
# 필요한 Lib을 Import한 후, Colab을 이용해 데이터셋을 load합니다.

from google.colab import files
import io
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

uploaded = files.upload()
# Out:
#      <input type="file" id="files-f62abccb-b3f1-49a9-af7a-f4778bc73c7a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f62abccb-b3f1-49a9-af7a-f4778bc73c7a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diamonds.csv to diamonds.csv

# %%
# 데이터셋을 확인합니다.

df=pd.read_csv(io.BytesIO(uploaded['filename.csv']))
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# ScatterPlot
sns.scatterplot(x='carat',y='price', data=data)

# %%
# BoxPlot
sns.boxplot(data=data, x='table', y='price')

# %%
# HeatMap
sns.heatmap(data=data.corr(),annot=True)

# %%
# FacetGrid Chart
g = sns.FacetGrid(data = data, col = 'clarity')

g.map_dataframe(
    sns.scatterplot,
    x = 'carat',
    y = 'price',
    hue = 'color',
    alpha = 0.5, # tranparency
    data = data,
)
g.add_legend();
